# %% [markdown]
# ## Importing Dependencies

# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from datetime import datetime
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %% [markdown]
# ## Executing the Chrome Driver

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
# executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# browser = Browser('chrome', **executable_path, headless=False)

# %%
browser = webdriver.Chrome()

# %% [markdown]
# ## For Windows Users

# %%
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## Importing Instagram User Information

# %%
instagramer = pd.read_csv('../../resources/users.csv')

insta_links = instagramer['link'][0:2].tolist()
# insta_names = instagramer['name'].tolist()
insta_names = instagramer['name'][0:2].tolist()
# insta_links = instagramer['link'].tolist()
instagramer.head()
# print(insta_links)
# Out:
#                                            link               name
# 0        https://www.instagram.com/taramilktea/        taramilktea
# 1        https://www.instagram.com/gypsea_lust/        gypsea_lust
# 2  https://www.instagram.com/travel_inhershoes/  travel_inhershoes
# 3       https://www.instagram.com/chelseakauai/       chelseakauai
# 4            https://www.instagram.com/hilvees/            hilvees

# %% [markdown]
# ## Scraping Instagram

# %%
# Scraping basic information on instagramers landing page as well as links for each of their posts.

anchors = {}
endpoints = []
userlist = []
followerslist = []
followinglist = []
postslist = []

for link in insta_links:
    
    try:
        browser.visit(link)
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        info = soup.find_all('meta', attrs={'property': 'og:description'})
        text = info[0].get('content').split()
        user = link.split('/')[3]
        followers = text[0]
        following = text[2]
        posts = text[4]
        userlist.append(user)
        followerslist.append(followers)
        followinglist.append(following)
        postslist.append(posts)

        for a in soup.find_all('a', href=True):
            
            if a['href'].startswith('/p/') == True:
                endpoints.append(link[:-1] + a['href'])
                anchors[user] = endpoints
                
            else:
                time.sleep(1.5)

    except MaxRetryError:
        print("You made too many calls!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-41b0e97e0030> in <module>()
#      33             else:
# ---> 34                 time.sleep(1.5)
#      35
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-41b0e97e0030> in <module>()
#      34                 time.sleep(1.5)
#      35
# ---> 36     except MaxRetryError:
#      37         print("You made too many calls!")
#
# NameError: name 'MaxRetryError' is not defined

# %%
# Scraping basic information on instagramers landing page as well as links for each of their posts.

anchors = {}
endpoints = []
userlist = []
followerslist = []
followinglist = []
postslist = []

# grabs updated html on browser;'/'
def getLinks(header):
    soup = BeautifulSoup(browser.page_source, 'html.parser')
    all_posts = [x.findAll('a', href=True) for x in soup.find("article", {"class": "FyNDV"})]
    links = [header + a['href'] for a in all_posts[0]]
    return links

def pushEnd():
    body.send_keys(Keys.END)
    time.sleep(1.5)
    
for link in insta_links:
    try:
        browser.get(link)
        html = browser.page_source
        soup = BeautifulSoup(html, 'html.parser')
        info = soup.find_all('meta', attrs={'property': 'og:description'})
        text = info[0].get('content').split()
        user = link.split('/')[3]
        followers = text[0]
        following = text[2]
        posts = text[4]
        userlist.append(user)
        followerslist.append(followers)
        followinglist.append(following)
        postslist.append(posts)
        headerURL = link[:-1]
        body = browser.find_element_by_tag_name("body")
# grab all href in article class FyNDV
# repeat 20x
# sets page to hold max amount of posts
        for x in range(3):
            pushEnd()
#         sets all current posts to endpoints list
        endpoints = getLinks(headerURL)
# modify number in range to change how many rows
        for x in range(20):
            pushEnd()
            nextLinks = getLinks(headerURL)
            length = len(nextLinks)
            # concats last 12 in nextLInks to endpoints
            endpoints += nextLinks[33:length]
        print(endpoints, len(endpoints))
    except:
        print("You made too many calls!")
# Out:
# ['https://www.instagram.com/taramilktea/p/Bv6fcsQlMlO/', 'https://www.instagram.com/taramilktea/p/Bv6S5SSFDKt/', 'https://www.instagram.com/taramilktea/p/Bv37-wYFqLx/', 'https://www.instagram.com/taramilktea/p/Bv3rq_olTDU/', 'https://www.instagram.com/taramilktea/p/Bv1XIvkFtwI/', 'https://www.instagram.com/taramilktea/p/Bv1HxSsFDS_/', 'https://www.instagram.com/taramilktea/p/Bvy2KBXFlFd/', 'https://www.instagram.com/taramilktea/p/Bvyqem7FICI/', 'https://www.instagram.com/taramilktea/p/BvwLEYkFabv/', 'https://www.instagram.com/taramilktea/p/Bvv5gUkFeth/', 'https://www.instagram.com/taramilktea/p/BvtZdH_lwL-/', 'https://www.instagram.com/taramilktea/p/BvtKeBgFSGo/', 'https://www.instagram.com/taramilktea/p/BvrIbIqFH9l/', 'https://www.instagram.com/taramilktea/p/BvrBYDiF_-D/', 'https://www.instagram.com/taramilktea/p/BvojRDvFsWm/', 'https://www.instagram.com/taramilktea/p/BvoFlW_lNMR/', 'https://www.instagram.com/taramilktea/p/BvkvDXjFEXt/', 'https://www.instagram.com/taramilktea/p/Bvjd_Gtl-RK/', 'https://www.instagram.com/taramilktea/p/Bvi5_h9ly81/', 'https://www.instagram.com/taramilktea/p/BvgTHm9FxO0/', 'https://www.instagram.com/taramilktea/p/Bvcv9Ryllus/', 'https://www.instagram.com/taramilktea/p/BvT8rg3FRqL/', 'https://www.instagram.com/taramilktea/p/BvL5mJgFBH5/', 'https://www.instagram.com/taramilktea/p/BvJPYNdl8bl/', 'https://www.instagram.com/taramilktea/p/BvG1fzzFxT9/', 'https://www.instagram.com/taramilktea/p/BvCAz8gFT6c/', 'https://www.instagram.com/taramilktea/p/BvB4v1wlFoq/', 'https://www.instagram.com/taramilktea/p/Bu_F5MXFTDb/', 'https://www.instagram.com/taramilktea/p/Bu6RkTblvvM/', 'https://www.instagram.com/taramilktea/p/Bu3QeVFliVy/', 'https://www.instagram.com/taramilktea/p/BuqmU5sl_z8/', 'https://www.instagram.com/taramilktea/p/Bullo1Pls4S/', 'https://www.instagram.com/taramilktea/p/BugePfPl7xo/', 'https://www.instagram.com/taramilktea/p/BugK8WvlHGG/', 'https://www.instagram.com/taramilktea/p/Bubahm3lVQZ/', 'https://www.instagram.com/taramilktea/p/BubLtZ1Fr2A/', 'https://www.instagram.com/taramilktea/p/BuY1v_iFa5R/', 'https://www.instagram.com/taramilktea/p/BuYAbltFNTN/', 'https://www.instagram.com/taramilktea/p/BuOfwomlcME/', 'https://www.instagram.com/taramilktea/p/BuJU3Cjlg8J/', 'https://www.instagram.com/taramilktea/p/BuIYWKUlmzQ/', 'https://www.instagram.com/taramilktea/p/BuGrXLIlQ8R/', 'https://www.instagram.com/taramilktea/p/Bt-4nmxlOOf/', 'https://www.instagram.com/taramilktea/p/Bt5hGpQlAmt/',
# %%
# Scraping each post for geotag for data
geolist = []
likesList = []
captionlist = []
datelist = []
taglist = []
tagdict = {}
for link in endpoints:
    try:
        browser.visit(link)        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        geotag = soup.find('a', class_="O4GlU").text
        date = soup.find('time')['datetime']
        caption_info = soup.find('div', class_ = 'C4VMK')
        caption = caption_info.find('span')
        captiontext = caption_info.find('span').text
#         tags = caption.find_all('a').text
        like_info = soup.find('a', class_='zV_Nj')
        likes_count = like_info.find('span').text
#         tagdict[link] = tags
        geolist.append(geotag)
#         taglist.append(tags)
        likesList.append(likes_count)
        captionlist.append(captiontext)
        datelist.append(date)
        time.sleep(1.5)
        
    except AttributeError:
        geolist.append('None')
        likesList.append('None')
        captionlist.append('None')
        datelist.append('None')
#         taglist.append('None')
        print(f'unable to pull certain info on this post: {link}')

# %%
# Scraping post links for geotag data
taglist = []
tagdict = {}
for link in endpoints:
    try:
        browser.visit(link)        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        caption_info = soup.find('div', class_ = 'C4VMK')
        caption = caption_info.find('span')
        captiontext = caption_info.find('span').text
        tags = caption.find_all('a', class_ = 'notranslate')
        taglist.append(tags)
        
        for tag in taglist:
            tagtext = tag.text
            
            if link not in tagdict.keys():
                tagdict[link] = taglist
                
            else:
                tagdict[link].append(taglist)
            
        time.sleep(1.5)
        
    except AttributeError:
        taglist.append('None')
        print(f'unable to pull certain info on this post: {link}')

# %%
# print(anchors)
print(tagdict)
# print(tags)
# print(tagtext)
# print(taglist)
# print(endpoints)
# print(geolist)
# print(caption)
# print(likes_count)
# print(date)
# print(user)

# len(endpoints)
# Out:
# {}

# %% [markdown]
# ## Creating Dataframes

# %%
page_df = pd.DataFrame(userlist)

# data = [[user, link]
#         for user, link in anchors.items()
#         for link_num in link]

post_df = pd.DataFrame(endpoints)

post_df.head()

# page_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
post_df['geotag'] = geolist
post_df['caption'] = captionlist
post_df['# of likes'] = likesList
post_df['date posted'] = datelist

page_df['followers'] = followerslist
page_df['following'] = followinglist
page_df['post count'] = postslist

# %%
# Cleaning up the data and adjusting the datatypes

post_df.rename(columns={0:'post link'}, inplace = True)
page_df.rename(columns={0:'user'}, inplace = True)

post_dflist = post_df['post link'].tolist()
usernames = [postsplit.split('/')[3] for postsplit in post_dflist]
post_df['users'] = usernames
post_df = post_df[['users', 'post link', 'date posted', 'geotag', 'caption', '# of likes']]

post_df.replace('None', np.nan, inplace=True)
page_df.replace('None', np.nan, inplace=True)

page_df['followers'] = (page_df['followers'].replace(r'[km]+$', '', regex=True).astype(float) * \
page_df['followers'].str.extract(r'[\d\.]+([km]+)', expand=False)
.fillna(1).replace(['k','m'], [10**3, 10**6]).astype(int))

post_df.dropna(axis=0, how='any', inplace= True)
post_df['# of likes'] = post_df['# of likes'].str.replace(',', '')
post_df['# of likes'] = post_df['# of likes'].astype(int)


post_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'post link'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-722d7f2e18a1> in <module>()
#       4 page_df.rename(columns={0:'user'}, inplace = True)
#       5
# ----> 6 post_dflist = post_df['post link'].tolist()
#       7 usernames = [postsplit.split('/')[3] for postsplit in post_dflist]
#       8 post_df['users'] = usernames
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'post link'

# %%
post_df['date posted'] = post_df['date posted'].astype(str)
datesList = post_df['date posted'].tolist()
updatedDates = [date[0:10] for date in datesList]
post_df['date posted'] = updatedDates
post_df['date posted'] = pd.to_datetime(post_df['date posted'], format = '%Y-%m-%d')
# print(updatedDates)
post_df.dtypes
# Out:
# geotag                float64
# caption               float64
# # of likes            float64
# date posted    datetime64[ns]
# dtype: object

# %%
page_df['post count'] = page_df['post count'].str.replace(',', '')
page_df['post count'] = page_df['post count'].astype(int)

page_df['followers'] = page_df['followers'].astype(int)

page_df['following'] = page_df['following'].astype(int)

page_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0a9b84b92915> in <module>()
#       2
#       3
# ----> 4 page_df['post count'] = page_df['post count'].str.replace(',', '')
#       5 page_df['post count'] = page_df['post count'].astype(int)
#       6
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, instance, owner)
#      52             # this ensures that Series.str.<method> is well defined
#      53             return self.accessor_cls
# ---> 54         return self.construct_accessor(instance)
#      55
#      56     def __set__(self, instance, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/strings.py in _make_accessor(cls, data)
#    1908             # (instead of test for object dtype), but that isn't practical for
#    1909             # performance reasons until we have a str dtype (GH 9343)
# -> 1910             raise AttributeError("Can only use .str accessor with string "
#    1911                                  "values, which use np.object_ dtype in "
#    1912                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
page_df.head(50)
# page_df.to_sql()
# page_df.shape
# Out:
# Empty DataFrame
# Columns: [followers, following, post count]
# Index: []

# %%
post_df.head(100)
# post_df.shape
# Out:
#           users                                          post link  \
# 0   taramilktea  https://www.instagram.com/taramilktea/p/BwZZrr...
# 1   taramilktea  https://www.instagram.com/taramilktea/p/BwWlO7...
# 2   taramilktea  https://www.instagram.com/taramilktea/p/BwUCeY...
# 3   taramilktea  https://www.instagram.com/taramilktea/p/BwMjYO...
# 4   taramilktea  https://www.instagram.com/taramilktea/p/BwKLji...
# 5   taramilktea  https://www.instagram.com/taramilktea/p/BwJ6ej...
# 6   taramilktea  https://www.instagram.com/taramilktea/p/BwE2oM...
# 7   taramilktea  https://www.instagram.com/taramilktea/p/BwCMpd...
# 8   taramilktea  https://www.instagram.com/taramilktea/p/Bv_4zD...
# 9   taramilktea  https://www.instagram.com/taramilktea/p/Bv_dOp...
# 10  taramilktea  https://www.instagram.com/taramilktea/p/Bv9SjY...
# 11  taramilktea  https://www.instagram.com/taramilktea/p/Bv9Byw...
# 12  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwW14E...
# 13  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwO9Qr...
# 15  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwIWEZ...
# 16  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwE01n...
# 17  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwCcu8...
# 18  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv_7mI...
# 20  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv6jYJ...
# 21  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv4l83...
# 22  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv2CgM...
# 23  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bvy-HH...
#
#    date posted                                            geotag  \
# 0   2019-04-18                             W Shanghai - The Bund
# 1   2019-04-17                             W Shanghai - The Bund
# 2   2019-04-16                                   Shanghai, China
# 3   2019-04-13                        Park Hyatt Seoul - 파크하얏트서울
# 4   2019-04-12                    Jinhae, Kyŏngsang-Namdo, Korea
# 5   2019-04-12                        Park Hyatt Seoul - 파크하얏트서울
# 6   2019-04-10                                           Jogyesa
# 7   2019-04-09                                 Starfield Library
# 8   2019-04-08                        Park Hyatt Busan - 파크하얏트부산
# 9   2019-04-08                             Bukchon Hanok Village
# 10  2019-04-07                         Line Friends Store & Cafe
# 11  2019-04-07                                         Insa-dong
# 12  2019-04-17                                Udaipur, Rajasthan
# 13  2019-04-14                                Marrakech-Moroco ღ
# 15  2019-04-11  La Maison-The House /  Private Riad in Marrakech
# 16  2019-04-10                                         Marrakech
# 17  2019-04-09                                   Le Riad Yasmine
# 18  2019-04-08                                         Marrakech
# 20  2019-04-06                                         Marrakech
# 21  2019-04-05                           Agafay Désert Marrakech
# 22  2019-04-04                           Agafay Désert Marrakech
# 23  2019-04-03                                             India
#
#                                               caption  # of likes
# 0                      Shanghai nights 🇨🇳✨ @wshanghai       38139
# 1      Shanghai is living in the future ⚡️ @wshanghai       81365
# 2   我來到了上海 ! 🇨🇳 I’m here with @grouperenault for R...       32958
# 3   Sunset swim 🌞 @parkhyattseoul @Hyatt #WorldOfH...       37459
# 4   The magic of Jinhae ✨🌸☂️✨ I’m so glad we were ...       55375
# 5   Thank you for your magic. I can’t wait to be b...       52502
# 6                               When in Seoul 🥰🧡❤️💚💖💙       31519
# 7   Find me among the shelves 📚 Stopped by the Sta...       76815
# 8   Dreamy interiors at our home away from home in...       35883
# 9                                        한복 details 🌸       45942
# 10                                                 🐻🐻       33363
# 11  The white lanterns at Jogyesa temple represent...       38152
# 12                               Sweet like honey 🍯 💛       53449
# 13  Queen of multitasking- laundry, tanning & gett...       47479
# 15  Morocco will always have a special place in my...       34246
# 16  ‘Actually, the best gift you could have given ...       39485
# 17  Spending my last moments in Morrocco with a li...       28913
# 18  Treasure hunting in Morocco 🇲🇦 happy to say we...       47459
# 20  Lunch above the Marrakech Souk, I spy many rug...       33812
# 21  This desert camp was the perfect setting to di...       35207
# 22  Back discovering again with @Chloe for the #Ch...       29524
# 23  Dreaming of being back in India. In the meanti...       47124

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql://root:{password}@localhost/instagramDB?charset=utf8mb4", encoding='utf-8')
def main():
    page_df.to_sql(name="page",index=False,con=engine,if_exists='replace')
    post_df.to_sql(name="post",index=False,con=engine,if_exists='replace')

if __name__=="__main__":
    main()
