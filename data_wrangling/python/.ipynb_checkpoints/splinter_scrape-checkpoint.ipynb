# %% [markdown]
# ## Importing Dependencies

# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Executing the Chrome Driver

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## For Windows Users

# %%
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## Importing Instagram User Information

# %%
instagramer = pd.read_csv('../../resources/users.csv')
insta_names = instagramer['name'].tolist()
insta_links = instagramer['link'].tolist()
instagramer.head()
# Out:
#                                            link               name
# 0        https://www.instagram.com/taramilktea/        taramilktea
# 1        https://www.instagram.com/gypsea_lust/        gypsea_lust
# 2  https://www.instagram.com/travel_inhershoes/  travel_inhershoes
# 3       https://www.instagram.com/chelseakauai/       chelseakauai
# 4            https://www.instagram.com/hilvees/            hilvees

# %% [markdown]
# ## Scraping Instagram

# %%
# Scraping basic information on instagramers landing page as well as links for each of their posts.

anchors = {}
endpoints = []
userlist = []
followerslist = []
followinglist = []
postslist = []

for link in insta_links:
    try:
        browser.visit(link)
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        info = soup.find_all('meta', attrs={'property': 'og:description'})
        text = info[0].get('content').split()
        user = link.split('/')[3]
        followers = text[0]
        following = text[2]
        posts = text[4]
        userlist.append(user)
        followerslist.append(followers)
        followinglist.append(following)
        postslist.append(posts)

        for a in soup.find_all('a', href=True):
            
            if a['href'].startswith('/p/') == True:
                endpoints.append(link[:-1] + a['href'])
                anchors[user] = endpoints
                
            else:
                time.sleep(1.5)

    except MaxRetryError:
        print("You made too many calls!")

# %%
# Scraping each post for geotag for data
geolist = []
likesList = []
captionlist = []
datelist = []

for link in endpoints:
    try:
        browser.visit(link)        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        geotag = soup.find('a', class_="O4GlU").text
        date = soup.find('time')['datetime']
        caption_info = soup.find('div', class_ = 'C4VMK')
        caption = caption_info.find('span')
        captiontext = caption_info.find('span').text
        like_info = soup.find('a', class_='zV_Nj')
        likes_count = like_info.find('span').text
        geolist.append(geotag)
        likesList.append(likes_count)
        captionlist.append(captiontext)
        datelist.append(date)
        time.sleep(1.5)
        
    except AttributeError:
        geolist.append('None')
        likesList.append('None')
        captionlist.append('None')
        datelist.append('None')
        print(f'unable to pull certain info on this post: {link}')
# Out:
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwL_UWLFvnc/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bv9Obi9lPx0/
# unable to pull certain info on this post: https://www.instagram.com/chelseakauai/p/Bu9Gxj_Bf9V/
# unable to pull certain info on this post: https://www.instagram.com/hilvees/p/BwFydkMF0Nu/
# unable to pull certain info on this post: https://www.instagram.com/jess.wandering/p/BwR9w34h1s_/
# unable to pull certain info on this post: https://www.instagram.com/samkolder/p/Bwc6LR5ojSO/
# unable to pull certain info on this post: https://www.instagram.com/samkolder/p/BvOn94ahDqh/
# unable to pull certain info on this post: https://www.instagram.com/samkolder/p/BuJdd-gBlT_/
# unable to pull certain info on this post: https://www.instagram.com/samkolder/p/BtyQMVdhmZx/
# unable to pull certain info on this post: https://www.instagram.com/wonguy974/p/BwJW35BoyOA/
# unable to pull certain info on this post: https://www.instagram.com/helloemilie/p/BvY9ZF2DCnL/
# unable to pull certain info on this post: https://www.instagram.com/jasoncharleshill/p/BwCPt5qBmug/
# unable to pull certain info on this post: https://www.instagram.com/jasoncharleshill/p/BvtizeZhg8L/
# unable to pull certain info on this post: https://www.instagram.com/irinahp/p/BwRh1n3gz7t/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwkVqCLhDKC/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/Bwac0XNBO94/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwYkVfChsYj/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwViVD6B__s/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwSqxn9Bjgw/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwLTckaBbyw/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwIopdNBnV1/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwDmZ27h3S-/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/BwBBPw8hHzV/
# unable to pull certain info on this post: https://www.instagram.com/foodwithmichel/p/Bv5SmfQhs6W/
# unable to pull certain info on this post: https://www.instagram.com/oliviavlopez/p/BwkOIl2nT0r/
# unable to pull certain info on this post: https://www.instagram.com/oliviavlopez/p/Bwj9tdGnBUL/
# unable to pull certain info on this post: https://www.instagram.com/oliviavlopez/p/BwhNInOHIBv/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwkP6OAFFCa/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwVDqkilnZ3/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwSHhT_Fb5m/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwQMXdIlkL_/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwNJbBFlULc/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwNHsVEFWKV/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwKPZ9YFKrj/
# unable to pull certain info on this post: https://www.instagram.com/weylie/p/BwH_-1OF9dR/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwkPX-MgWf8/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwijDIZgXGy/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwhT2u7g7O5/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwaN8c6g3Rv/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwU7E1hApCV/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwM-8jcgXb7/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwLZuykgQ-f/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwIr6VggfKA/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwH0Avfg8lU/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwGTXMuA2SJ/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwFuU_XAM9f/
# unable to pull certain info on this post: https://www.instagram.com/kerenswan/p/BwDGPYjAvhF/
# unable to pull certain info on this post: https://www.instagram.com/hobopeeba/p/BweYDRJC5EP/
# unable to pull certain info on this post: https://www.instagram.com/hobopeeba/p/BwZq_1WignJ/
# unable to pull certain info on this post: https://www.instagram.com/hobopeeba/p/BwE5iM2ilPo/
# unable to pull certain info on this post: https://www.instagram.com/cabinfeed/p/BwOpaTgFyDL/
# unable to pull certain info on this post: https://www.instagram.com/cabinfeed/p/Bv4YEwugeXm/
# unable to pull certain info on this post: https://www.instagram.com/cabinfeed/p/Bvn4jgWgY0Q/
# unable to pull certain info on this post: https://www.instagram.com/kalenemsley/p/BqoVlmDFyHq/
# unable to pull certain info on this post: https://www.instagram.com/saltyluxe/p/BwdP8lIFnzF/
# unable to pull certain info on this post: https://www.instagram.com/saltyluxe/p/BwAr18Cl3A4/
# unable to pull certain info on this post: https://www.instagram.com/storyofsage/p/BsCQc8LnPQ3/
# unable to pull certain info on this post: https://www.instagram.com/amebeverly/p/BwexKk2H_Ck/
# unable to pull certain info on this post: https://www.instagram.com/hilvees/p/BwFydkMF0Nu/
# unable to pull certain info on this post: https://www.instagram.com/doyoutravel/p/BwP0BfoB2_v/
# unable to pull certain info on this post: https://www.instagram.com/doyoutravel/p/BvyvlZ4hB7s/
# unable to pull certain info on this post: https://www.instagram.com/alexiistherese/p/BwbIZ7Qhvdn/
# unable to pull certain info on this post: https://www.instagram.com/alexiistherese/p/BwWACochEIX/
# unable to pull certain info on this post: https://www.instagram.com/alexiistherese/p/BwTRTyzhpJi/
# unable to pull certain info on this post: https://www.instagram.com/alexiistherese/p/BwLokSIhEx1/
# unable to pull certain info on this post: https://www.instagram.com/alexiistherese/p/BwJEml9hTeM/
# unable to pull certain info on this post: https://www.instagram.com/ryanresatka/p/Bwj7bAfB95V/
# unable to pull certain info on this post: https://www.instagram.com/jlinhh/p/BwGC6hABt_m/

# %% [markdown]
# ## Creating Dataframes

# %%
page_df = pd.DataFrame(userlist)
post_df = pd.DataFrame(endpoints)

# post_df.head()
# page_df.head()

# %%
post_df['geotag'] = geolist
post_df['caption'] = captionlist
post_df['# of likes'] = likesList
post_df['date posted'] = datelist

page_df['followers'] = followerslist
page_df['following'] = followinglist
page_df['post count'] = postslist

# %%
# Cleaning up the data and adjusting the datatypes

post_df.rename(columns={0:'post link'}, inplace = True)
page_df.rename(columns={0:'user'}, inplace = True)

post_dflist = post_df['post link'].tolist()
usernames = [postsplit.split('/')[3] for postsplit in post_dflist]
post_df['users'] = usernames
post_df = post_df[['users', 'post link', 'date posted', 'geotag', 'caption', '# of likes']]

post_df.replace('None', np.nan, inplace=True)
page_df.replace('None', np.nan, inplace=True)

page_df['followers'] = (page_df['followers'].replace(r'[km]+$', '', regex=True).astype(float) * \
page_df['followers'].str.extract(r'[\d\.]+([km]+)', expand=False)
.fillna(1).replace(['k','m'], [10**3, 10**6]).astype(int))

post_df.dropna(axis=0, how='any', inplace= True)
post_df['# of likes'] = post_df['# of likes'].str.replace(',', '')
post_df['# of likes'] = post_df['# of likes'].astype(int)


post_df.dtypes
# Out:
# users          object
# post link      object
# date posted    object
# geotag         object
# caption        object
# # of likes      int64
# dtype: object

# %%
post_df['date posted'] = post_df['date posted'].astype(str)
datesList = post_df['date posted'].tolist()
updatedDates = [date[0:10] for date in datesList]
post_df['date posted'] = updatedDates
post_df['date posted'] = pd.to_datetime(post_df['date posted'], format = '%Y-%m-%d')
# print(updatedDates)
post_df.dtypes
# Out:
# users                  object
# post link              object
# date posted    datetime64[ns]
# geotag                 object
# caption                object
# # of likes              int64
# dtype: object

# %%
page_df['post count'] = page_df['post count'].str.replace(',', '')
page_df['post count'] = page_df['post count'].astype(int)

page_df['followers'] = page_df['followers'].astype(int)
page_df['following']  = page_df['following'].str.replace(',', '')
page_df['following'] = page_df['following'].astype(int)

page_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-fa4425c5ac3f> in <module>()
# ----> 1 page_df['post count'] = page_df['post count'].str.replace(',', '')
#       2 page_df['post count'] = page_df['post count'].astype(int)
#       3
#       4 page_df['followers'] = page_df['followers'].astype(int)
#       5 page_df['following']  = page_df['following'].str.replace(',', '')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3608         if (name in self._internal_names_set or name in self._metadata or
#    3609                 name in self._accessors):
# -> 3610             return object.__getattribute__(self, name)
#    3611         else:
#    3612             if name in self._info_axis:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, instance, owner)
#      52             # this ensures that Series.str.<method> is well defined
#      53             return self.accessor_cls
# ---> 54         return self.construct_accessor(instance)
#      55
#      56     def __set__(self, instance, value):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/strings.py in _make_accessor(cls, data)
#    1908             # (instead of test for object dtype), but that isn't practical for
#    1909             # performance reasons until we have a str dtype (GH 9343)
# -> 1910             raise AttributeError("Can only use .str accessor with string "
#    1911                                  "values, which use np.object_ dtype in "
#    1912                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
page_df.head(50)
# page_df.to_sql()
# page_df.shape
# Out:
#                   user  followers following  post count
# 0          taramilktea    1200000       640        1749
# 1          gypsea_lust    2100000       340        1344
# 2    travel_inhershoes     891900       989        1410
# 3         chelseakauai     736300       580        1114
# 4              hilvees     456200       107        1112
# 5       jess.wandering     650800       346         652
# 6            samkolder    1300000       481         437
# 7            wonguy974     246100       360        1355
# 8            noel.alva     257899       102         158
# 9            leahliyah     113800       517         148
# 10         helloemilie    1200000       422        1199
# 11    jasoncharleshill     521200       457        1225
# 12             irinahp     252900       651        2587
# 13      foodwithmichel     296100       188         973
# 14        oliviavlopez     351900       730        2983
# 15    travelgram_korea     149400        54         438
# 16              weylie     478200       750        3250
# 17           kerenswan     470600       448        1081
# 15   Queen of multitasking- laundry, tanning & gett...       48261
# 17   Morocco will always have a special place in my...       34597
# 18   ‘Actually, the best gift you could have given ...       39851
# 19   Spending my last moments in Morrocco with a li...       29133
# 20   Treasure hunting in Morocco 🇲🇦 happy to say we...       47715
# 22   Lunch above the Marrakech Souk, I spy many rug...       33921
# 23   This desert camp was the perfect setting to di...       35328
# 24   You are only free when you realize you belong ...       29576
# 25   Somewhere someone is looking for you in every ...       32733
# 26   Channeling my inner Dirty Dancing 💃🏼🎡🕊 with @g...       59540
# 27   What a weekend it’s been! 🎡🎢 Thank you @absolu...       20725
# 28   Cheers to the festival time! Arrived in Palm S...       25166
# 29   I want someone to look at me the way I look at...       32095
# 30   Counting down the days ✌🏻✌🏻✌🏻 — who’s coming a...       41040
# 31   I hope the very best for you. I hope you are a...       30117
# ..                                                 ...         ...
# 77   From my trip with @indtravel exploring off the...      134137
# 78   Dropping a vlog this week from indonesia 🤙🏽 Cu...      160522
# 80   Work hard in silence. Let your work make the n...      123413
# 81   To the girl that's brought another level of ex...      185101
# 83   The incredibly frigid yet beautiful Lapland. ❄...      155196
# 84   A RAINBOW OF TULIPS 🌈 1, 2 or 3 ? It is amazin...       17641
# 85   TULIP PARADISE 🌷 Couldn’t be more blessed than...       14001
# 86   HELLO NETHERLANDS 🇳🇱 About this morning sunris...        8846
# 87   Currently on my way to chase some Tulip fields...       17204
# 88   FLUCTUAT NEC MERGITUR 💛 Still moved this morni...       27947
# 89   Guys, this is happening right now in Paris ......       57453
# 90   Back to the city of lights ✨ One of my favorit...       18101
# 91   Weekend getaway 💚 Ce week-end, nous avons la c...        7044
# 93   CLASSIC BLOOM 🌸 1, 2 or 3 ? Every Springtime, ...       14472
# 94   Full bloom season in Paris 🌸 So good to see al...       13621
# 95   Back to Paris right on time for the cherry blo...       12170
# 96   Let’s go to far off places. 🚂💫🌌 Model: @chloeb...       12392
# 97   Grow from within, always. 🌱💚 My NEW Lightroom ...       11418
# 98   I will always be here to keep you afloat. 💙💎 M...        9938
# 99   Do you still dream of me like I dream of you? ...       13225
# 100  I forget to fear when you’re near. 🦋💙💎🌊🙏🏽 (I’m...       12498
# 101  I’ll carry your words with me wherever I go. 🚎...        8951
# 102  When’s the last time you did something for the...       14376
# 103  How rare & beautiful it is to even exist. 🌅🙏🏽 ...        9541
# 104  Reach as high as your arms, heart, & mind allo...        9883
# 105  Dream higher & higher. Always. 💎🦋🌌🌃 Model: @al...       15265
# 106  I know it feels like drowning, but you’ll resu...       12178
# 107  Grow up, but don’t grow old. Remember & return...       14185
# 108  Got to stay at the top rated Airbnb in NYC⚡️⚡️...       13023
# 109             My 6th year living in my fav city ⚡️⚡️        7924
#
# [100 rows x 6 columns]

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql://root:Beeonwindow1!@localhost/instagramDB?charset=utf8mb4", encoding='utf-8')
def main():
    page_df.to_sql(name="page",index=False,con=engine,if_exists='replace')
    post_df.to_sql(name="post",index=False,con=engine,if_exists='replace')

if __name__=="__main__":
    main()
