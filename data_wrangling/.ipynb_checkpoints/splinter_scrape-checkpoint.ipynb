# %% [markdown]
# ## Importing Dependencies

# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import pprint
import pandas as pd
import time
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Executing the Chrome Driver

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## For Windows Users

# %%
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ## Importing Instagram User Information

# %%
instagramer = pd.read_csv('../../resources/users.csv')

insta_links = instagramer['link'][0:2].tolist()
# insta_names = instagramer['name'].tolist()
insta_names = instagramer['name'][0:2].tolist()
# insta_links = instagramer['link'].tolist()
instagramer.head()
# print(insta_links)
# Out:
#                                            link               name
# 0        https://www.instagram.com/taramilktea/        taramilktea
# 1        https://www.instagram.com/gypsea_lust/        gypsea_lust
# 2  https://www.instagram.com/travel_inhershoes/  travel_inhershoes
# 3       https://www.instagram.com/chelseakauai/       chelseakauai
# 4            https://www.instagram.com/hilvees/            hilvees

# %% [markdown]
# ## Scraping Instagram

# %%
# Scraping basic information on instagramers landing page as well as links for each of their posts.

anchors = {}
endpoints = []
userlist = []
followerslist = []
followinglist = []
postslist = []

for link in insta_links:
    try:
        browser.visit(link)
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        info = soup.find_all('meta', attrs={'property': 'og:description'})
        text = info[0].get('content').split()
        user = link.split('/')[3]
        followers = text[0]
        following = text[2]
        posts = text[4]
        userlist.append(user)
        followerslist.append(followers)
        followinglist.append(following)
        postslist.append(posts)

        for a in soup.find_all('a', href=True):
            
            if a['href'].startswith('/p/') == True:
                endpoints.append(link[:-1] + a['href'])
                anchors[user] = endpoints
                
            else:
                time.sleep(1.5)

    except MaxRetryError:
        print("You made too many calls!")

# %%
# Scraping each post for geotag for data
geolist = []
likesList = []
captionlist = []
datelist = []
taglist = []
tagdict = {}
for link in endpoints:
    try:
        browser.visit(link)        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        geotag = soup.find('a', class_="O4GlU").text
        date = soup.find('time')['title']
        caption_info = soup.find('div', class_ = 'C4VMK')
        caption = caption_info.find('span')
        captiontext = caption_info.find('span').text
#         tags = caption.find_all('a').text
        like_info = soup.find('a', class_='zV_Nj')
        likes_count = like_info.find('span').text
#         tagdict[link] = tags
        geolist.append(geotag)
#         taglist.append(tags)
        likesList.append(likes_count)
        captionlist.append(captiontext)
        datelist.append(date)
        time.sleep(1.5)
        
    except AttributeError:
        geolist.append('None')
        likesList.append('None')
        captionlist.append('None')
        datelist.append('None')
#         taglist.append('None')
        print(f'unable to pull certain info on this post: {link}')
# Out:
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwL_UWLFvnc/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bv9Obi9lPx0/

# %%
# Scraping post links for geotag data
taglist = []
tagdict = {}
for link in endpoints:
    try:
        browser.visit(link)        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        caption_info = soup.find('div', class_ = 'C4VMK')
        caption = caption_info.find('span')
        captiontext = caption_info.find('span').text
        tags = caption.find_all('a', class_ = 'notranslate')
        taglist.append(tags)
        
        for tag in taglist:
            tagtext = tag.text
            
            if link in tagdict.keys():
                tagdict[link].append(taglist)
                
            else:
                tagdict[link] = taglist
            
        time.sleep(1.5)
        
    except AttributeError:
        taglist.append('None')
        print(f'unable to pull certain info on this post: {link}')
# Out:
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwZZrrnljeV/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwWlO75FK0z/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwUCeY1Fd-M/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwMjYOTFTJD/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwKLjiTFdXE/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwJ6ej6l1W8/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwE2oMGlGgj/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/BwCMpdylVGY/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/Bv_4zDGlKlu/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/Bv_dOpnlo1W/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/Bv9SjY-Fpm4/
# unable to pull certain info on this post: https://www.instagram.com/taramilktea/p/Bv9BywalwkR/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwW14EhJKqF/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwO9QrxpaIV/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwL_UWLFvnc/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwIWEZbJUdo/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwE01nlpnV-/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/BwCcu8jF7mN/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bv_7mIvl1qf/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bv9Obi9lPx0/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bv6jYJiFtrh/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bv4l830lPuu/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bv2CgMrli0-/
# unable to pull certain info on this post: https://www.instagram.com/gypsea_lust/p/Bvy-HHsFMWy/

# %%
# print(anchors)
# print(tagdict)
# print(tags)
# print(tagtext)
print(taglist)
# print(endpoints)
# print(geolist)
# print(caption)
# print(likes_count)
# print(date)
# print(user)

# len(endpoints)
# Out:
# [[<a class="notranslate" href="/wshanghai/">@wshanghai</a>], 'None', [<a class="notranslate" href="/wshanghai/">@wshanghai</a>], 'None', [<a class="notranslate" href="/grouperenault/">@grouperenault</a>], 'None', [<a class="notranslate" href="/parkhyattseoul/">@parkhyattseoul</a>, <a class="notranslate" href="/Hyatt/">@Hyatt</a>], 'None', [<a class="notranslate" href="/parkhyattbusan/">@parkhyattbusan</a>, <a class="notranslate" href="/hyatt/">@hyatt</a>], 'None', [<a class="notranslate" href="/parkhyattseoul/">@parkhyattseoul</a>, <a class="notranslate" href="/Hyatt/">@Hyatt</a>], 'None', [], 'None', [<a class="notranslate" href="/parkhyattseoul/">@parkhyattseoul</a>, <a class="notranslate" href="/Hyatt/">@Hyatt</a>], 'None', [<a class="notranslate" href="/parkhyattbusan/">@parkhyattbusan</a>, <a class="notranslate" href="/Hyatt/">@Hyatt</a>], 'None', [], 'None', [], 'None', [], 'None', [], 'None', [], 'None', [], 'None', [<a class="notranslate" href="/Chloe/">@Chloe</a>, <a class="notranslate" href="/Sephora/">@Sephora</a>], 'None', [], 'None', [<a class="notranslate" href="/morroccomethod/">@morroccomethod</a>], 'None', [], 'None', [<a class="notranslate" href="/lepetityasmine/">@lepetityasmine</a>], 'None', [], 'None', [<a class="notranslate" href="/Chloe/">@Chloe</a>, <a class="notranslate" href="/Sephora/">@Sephora</a>], 'None', [<a class="notranslate" href="/Chloe/">@Chloe</a>, <a class="notranslate" href="/sephora/">@sephora</a>], 'None', [<a class="notranslate" href="/marc.fisher/">@marc.fisher</a>], 'None']

# %% [markdown]
# ## Creating Dataframes

# %%
page_df = pd.DataFrame(userlist)

# data = [[user, link]
#         for user, link in anchors.items()
#         for link_num in link]

post_df = pd.DataFrame(endpoints)

post_df.head()

# page_df.head()
# Out:
#                                                    0
# 0  https://www.instagram.com/taramilktea/p/BwWlO7...
# 1  https://www.instagram.com/taramilktea/p/BwUCeY...
# 2  https://www.instagram.com/taramilktea/p/BwMjYO...
# 3  https://www.instagram.com/taramilktea/p/BwKLji...
# 4  https://www.instagram.com/taramilktea/p/BwJ6ej...

# %%
post_df['geotag'] = geolist
post_df['caption'] = captionlist
post_df['# of likes'] = likesList
post_df['date posted'] = datelist

page_df['followers'] = followerslist
page_df['following'] = followinglist
page_df['post count'] = postslist

# %%
post_df.rename(columns={0:'post link'}, inplace = True)
page_df.rename(columns={0:'user'}, inplace = True)

# %%
post_dflist = post_df['post link'].tolist()
usernames = [postsplit.split('/')[3] for postsplit in post_dflist]
post_df['users'] = usernames
post_df = post_df[['users', 'post link', 'date posted', 'geotag', 'caption', '# of likes']]

post_df.replace('None', np.nan, inplace=True)
page_df.replace('None', np.nan, inplace=True)

page_df['followers'] = (page_df['followers'].replace(r'[km]+$', '', regex=True).astype(float) * \
page_df['followers'].str.extract(r'[\d\.]+([km]+)', expand=False)
.fillna(1).replace(['k','m'], [10**3, 10**6]).astype(int))

post_df.dropna(axis=0, how='any', inplace= True)
post_df['# of likes'] = post_df['# of likes'].str.replace(',', '')
post_df['# of likes'] = post_df['# of likes'].astype(int)

post_df['date posted'] = post_df['date posted'].astype(str)

# post_df['date posted'] = datetime.strptime(post_df['date posted'], '%A %d, %Y')

page_df['post count'] = page_df['post count'].str.replace(',', '')
page_df['post count'] = page_df['post count'].astype(int)


post_df.dtypes
# Out:
# users          object
# post link      object
# date posted    object
# geotag         object
# caption        object
# # of likes      int64
# dtype: object

# %%
page_df.head(50)
# page_df.to_sql()
# page_df.shape
# Out:
#           user  followers following  post count
# 0  taramilktea  1200000.0       636        1746
# 1  gypsea_lust  2100000.0       340        1342

# %%
post_df.head(100)
# post_df.shape
# Out:
#           users                                          post link  \
# 0   taramilktea  https://www.instagram.com/taramilktea/p/BwWlO7...
# 1   taramilktea  https://www.instagram.com/taramilktea/p/BwUCeY...
# 2   taramilktea  https://www.instagram.com/taramilktea/p/BwMjYO...
# 3   taramilktea  https://www.instagram.com/taramilktea/p/BwKLji...
# 4   taramilktea  https://www.instagram.com/taramilktea/p/BwJ6ej...
# 5   taramilktea  https://www.instagram.com/taramilktea/p/BwE2oM...
# 6   taramilktea  https://www.instagram.com/taramilktea/p/BwCMpd...
# 7   taramilktea  https://www.instagram.com/taramilktea/p/Bv_4zD...
# 8   taramilktea  https://www.instagram.com/taramilktea/p/Bv_dOp...
# 9   taramilktea  https://www.instagram.com/taramilktea/p/Bv9SjY...
# 10  taramilktea  https://www.instagram.com/taramilktea/p/Bv9Byw...
# 11  taramilktea  https://www.instagram.com/taramilktea/p/Bv6tBu...
# 12  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwW14E...
# 13  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwO9Qr...
# 15  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwIWEZ...
# 16  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwE01n...
# 17  gypsea_lust  https://www.instagram.com/gypsea_lust/p/BwCcu8...
# 18  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv_7mI...
# 20  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv6jYJ...
# 21  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv4l83...
# 22  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bv2CgM...
# 23  gypsea_lust  https://www.instagram.com/gypsea_lust/p/Bvy-HH...
#
#      date posted                                            geotag  \
# 0   Apr 17, 2019                             W Shanghai - The Bund
# 1   Apr 16, 2019                                   Shanghai, China
# 2   Apr 13, 2019                        Park Hyatt Seoul - 파크하얏트서울
# 3   Apr 12, 2019                    Jinhae, Kyŏngsang-Namdo, Korea
# 4   Apr 12, 2019                        Park Hyatt Seoul - 파크하얏트서울
# 5   Apr 10, 2019                                           Jogyesa
# 6    Apr 9, 2019                                 Starfield Library
# 7    Apr 8, 2019                        Park Hyatt Busan - 파크하얏트부산
# 8    Apr 8, 2019                             Bukchon Hanok Village
# 9    Apr 7, 2019                         Line Friends Store & Cafe
# 10   Apr 7, 2019                                         Insa-dong
# 11   Apr 6, 2019                         San Francisco, California
# 12  Apr 17, 2019                                Udaipur, Rajasthan
# 13  Apr 14, 2019                                Marrakech-Moroco ღ
# 15  Apr 11, 2019  La Maison-The House /  Private Riad in Marrakech
# 16  Apr 10, 2019                                         Marrakech
# 17   Apr 9, 2019                                   Le Riad Yasmine
# 18   Apr 8, 2019                                         Marrakech
# 20   Apr 6, 2019                                         Marrakech
# 21   Apr 5, 2019                           Agafay Désert Marrakech
# 22   Apr 4, 2019                           Agafay Désert Marrakech
# 23   Apr 3, 2019                                             India
#
#                                               caption  # of likes
# 0      Shanghai is living in the future ⚡️ @wshanghai       62474
# 1   我來到了上海 ! 🇨🇳 I’m here with @grouperenault for R...       31294
# 2   Sunset swim 🌞 @parkhyattseoul @Hyatt #WorldOfH...       37057
# 3   The magic of Jinhae ✨🌸☂️✨ I’m so glad we were ...       55149
# 4   Thank you for your magic. I can’t wait to be b...       52256
# 5                               When in Seoul 🥰🧡❤️💚💖💙       31358
# 6   Find me among the shelves 📚 Stopped by the Sta...       76440
# 7   Dreamy interiors at our home away from home in...       35778
# 8                                        한복 details 🌸       45807
# 9                                                  🐻🐻       33241
# 10  The white lanterns at Jogyesa temple represent...       38054
# 11  Full bloom in San Francisco 🌸 Our third episod...       32010
# 12                               Sweet like honey 🍯 💛       37172
# 13  Queen of multitasking- laundry, tanning & gett...       47071
# 15  Morocco will always have a special place in my...       34146
# 16  ‘Actually, the best gift you could have given ...       39356
# 17  Spending my last moments in Morrocco with a li...       28844
# 18  Treasure hunting in Morocco 🇲🇦 happy to say we...       47388
# 20  Lunch above the Marrakech Souk, I spy many rug...       33774
# 21  This desert camp was the perfect setting to di...       35159
# 22  Back discovering again with @Chloe for the #Ch...       29472
# 23  Dreaming of being back in India. In the meanti...       47095

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql://root:Beeonwindow1!@localhost/instagramDB?charset=utf8mb4", encoding='utf-8')
def main():
    page_df.to_sql(name="page",index=False,con=engine,if_exists='replace')
    post_df.to_sql(name="post",index=False,con=engine,if_exists='replace')

if __name__=="__main__":
    main()
